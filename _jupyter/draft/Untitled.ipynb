# %%
import os
import requests
from bs4 import BeautifulSoup

# %%
os.mkdir("emnlp")

# %%
def scrape_titles(url):
    headers = {
        "User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"
    }
    page = requests.get(url, headers=headers)
    soup = BeautifulSoup(page.text, "html.parser")
    papers = soup.find_all("span", class_="d-block")
    titles = [tag.find("a", class_="align-middle").text.strip() for tag in tags]
    titles = [title for title in titles if title != "pdf"][1:]
    return titles

# %%
titles_2019 = scrape_titles(url_2019)

# %%
titles_2019
# Out:
# ['Attending to Future Tokens for Bidirectional Sequence Generation',
#  'Attention is not not Explanation',
#  'Practical Obstacles to Deploying Active Learning',
#  'Transfer Learning Between Related Tasks Using Expected Label Proportions',
#  'Knowledge Enhanced Contextual Word Representations',
#  'How Contextual are Contextualized Word Representations? Comparing the Geometry of BERT, ELMo, and GPT-2 Embeddings',
#  'Room to Glo: A Systematic Comparison of Semantic Change Detection Approaches with Word Embeddings',
#  'Correlations between Word Vector Sets',
#  'Game Theory Meets Embeddings: a Unified Framework for Word Sense Disambiguation',
#  'Guided Dialog Policy Learning: Reward Estimation for Multi-Domain Task-Oriented Dialog',
#  'Multi-hop Selector Network for Multi-turn Response Selection in Retrieval-based Chatbots',
#  'MoEL: Mixture of Empathetic Listeners',
#  'Entity-Consistent End-to-end Task-Oriented Dialogue System with KB Retriever',
# ...

# %%
url_2020 = "https://www.aclweb.org/anthology/volumes/2020.emnlp-main/"
titles_2020 = scrape_titles(url_2020)
titles_2020
# Out:
# ['Attending to Future Tokens for Bidirectional Sequence Generation',
#  'Attention is not not Explanation',
#  'Practical Obstacles to Deploying Active Learning',
#  'Transfer Learning Between Related Tasks Using Expected Label Proportions',
#  'Knowledge Enhanced Contextual Word Representations',
#  'How Contextual are Contextualized Word Representations? Comparing the Geometry of BERT, ELMo, and GPT-2 Embeddings',
#  'Room to Glo: A Systematic Comparison of Semantic Change Detection Approaches with Word Embeddings',
#  'Correlations between Word Vector Sets',
#  'Game Theory Meets Embeddings: a Unified Framework for Word Sense Disambiguation',
#  'Guided Dialog Policy Learning: Reward Estimation for Multi-Domain Task-Oriented Dialog',
#  'Multi-hop Selector Network for Multi-turn Response Selection in Retrieval-based Chatbots',
#  'MoEL: Mixture of Empathetic Listeners',
#  'Entity-Consistent End-to-end Task-Oriented Dialogue System with KB Retriever',
# ...
